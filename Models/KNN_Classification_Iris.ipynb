# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el dataset de iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target

# Aplicar el algoritmo K-means con 3 clusters (ya que sabemos que hay 3 especies)
kmeans = KMeans(n_clusters=3, random_state=0)
df['cluster'] = kmeans.fit_predict(iris.data)

# Visualizar los clusters en 2D usando solo dos de las características
plt.figure(figsize=(10, 6))
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=df['cluster'], cmap='viridis', label="K-means clusters")
plt.xlabel('Sepal length (cm)')
plt.ylabel('Sepal width (cm)')
plt.title('Clustering de Iris con K-means')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ## K-NN
#
# Paso a Paso del Ejemplo de K-nearest neighbors (KNN)
# Cargar el Dataset Iris: Vamos a usar las cuatro características (longitud y ancho del sépalo y del pétalo) como variables independientes, y la especie de la flor como la variable objetivo.
#
# Dividir el Dataset: Dividimos el dataset en conjuntos de entrenamiento y prueba para evaluar la precisión del modelo.
#
# Configurar el Modelo KNN: Establecemos el número de vecinos k (por ejemplo, k=5) para hacer las predicciones. KNN busca los 5 vecinos más cercanos para clasificar cada muestra.
#
# Entrenar y Evaluar el Modelo: Entrenamos el modelo con el conjunto de entrenamiento y luego lo probamos en el conjunto de prueba para ver su precisión.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Cargar el dataset de iris
iris = load_iris()
X = iris.data  # Características
y = iris.target  # Etiquetas (especies de flores)

# Dividir el dataset en conjunto de entrenamiento y de prueba (70% entrenamiento, 30% prueba)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Configurar el modelo KNN con k=5 vecinos
knn = KNeighborsClassifier(n_neighbors=5)

# Entrenar el modelo con los datos de entrenamiento
knn.fit(X_train, y_train)

# Hacer predicciones en el conjunto de prueba
y_pred = knn.predict(X_test)

# Calcular la precisión del modelo
accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo KNN:", accuracy)
# Out:
# Precisión del modelo KNN: 0.9777777777777777

# %%
# Mostrar los nombres de las especies de flores en el dataset Iris
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ### Hacemos prediccion con un ejemplo

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# Cargar el dataset de iris
iris = load_iris()
X = iris.data  # Características
y = iris.target  # Etiquetas (especies de flores)

# Dividir el dataset en conjunto de entrenamiento y de prueba (70% entrenamiento, 30% prueba)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Configurar el modelo KNN con k=5 vecinos
knn = KNeighborsClassifier(n_neighbors=5)

# Entrenar el modelo con los datos de entrenamiento
knn.fit(X_train, y_train)

# Seleccionar una muestra del conjunto de prueba para predecir
sample_index = 0  # Escogemos la primera muestra en el conjunto de prueba
sample_data = X_test[sample_index].reshape(1, -1)  # Tomamos las características de esta muestra

# Predicción de la especie usando el modelo KNN
predicted_class = knn.predict(sample_data)[0]  # Clase predicha
actual_class = y_test[sample_index]  # Clase real

# Obtener los nombres de las especies
predicted_species = iris.target_names[predicted_class]
actual_species = iris.target_names[actual_class]

print("Predicción de la especie:", predicted_species)
print("Especie real:", actual_species)
# Out:
# Predicción de la especie: virginica
# Especie real: virginica

# %%
import numpy as np

# Generar valores aleatorios para cada característica en el rango aproximado del dataset Iris
random_sample = np.random.uniform(low=0, high=8, size=(1, 4))  # Generamos una muestra aleatoria con 4 características

# Usar el modelo KNN para predecir la especie de la muestra aleatoria
predicted_class_random = knn.predict(random_sample)[0]  # Clase predicha
predicted_species_random = iris.target_names[predicted_class_random]

random_sample, predicted_species_random
# Out:
# (array([[1.23892547, 4.59388242, 0.63411167, 1.96696953]]), np.str_('setosa'))
